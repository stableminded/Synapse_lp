# %% [markdown]
# <a href="https://colab.research.google.com/github/stableminded/Synapse_lp/blob/CV_Week_2/Dhairya_Mehta_Synapse_CV_Week_2_Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Image Segmentation ( Make sure you are using the T4 GPU Runtime )

# %% [markdown]
# This task focuses on <a href="https://www.v7labs.com/blog/image-segmentation-guide" class="external">Image Segmentation</a> and Object Detection.
#
# ## What is image segmentation?
#
# In an image classification task, the network assigns a label (or class) to each input image. However, suppose you want to know the shape of that object, which pixel belongs to which object, etc. In this case, you need to assign a class to each pixel of the image—this task is known as segmentation. A segmentation model returns much more detailed information about the image. Image segmentation has many applications in medical imaging, self-driving cars and satellite imaging, just to name a few.
#
# This task uses the [Oxford-IIIT Pet Dataset](https://www.robots.ox.ac.uk/~vgg/data/pets/) ([Parkhi et al, 2012](https://www.robots.ox.ac.uk/~vgg/publications/2012/parkhi12a/parkhi12a.pdf)). The dataset consists of images of 37 pet breeds, with 200 images per breed (~100 each in the training and test splits). Each image includes the corresponding labels, and pixel-wise masks. The masks are class-labels for each pixel. Each pixel is given one of three categories:
#
# - Class 1: Pixel belonging to the pet.
# - Class 2: Pixel bordering the pet.
# - Class 3: None of the above/a surrounding pixel.

# %% [markdown]
# ## Environment Setup

# %%
# !wget http://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz
# !wget http://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz
# !tar -xf images.tar.gz
# !tar -xf annotations.tar.gz
# Out:
# --2024-02-04 12:06:54--  http://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz
# Resolving www.robots.ox.ac.uk (www.robots.ox.ac.uk)... 129.67.94.2
# Connecting to www.robots.ox.ac.uk (www.robots.ox.ac.uk)|129.67.94.2|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz [following]
# --2024-02-04 12:06:54--  https://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz
# Connecting to www.robots.ox.ac.uk (www.robots.ox.ac.uk)|129.67.94.2|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://thor.robots.ox.ac.uk/~vgg/data/pets/images.tar.gz [following]
# --2024-02-04 12:06:55--  https://thor.robots.ox.ac.uk/~vgg/data/pets/images.tar.gz
# Resolving thor.robots.ox.ac.uk (thor.robots.ox.ac.uk)... 129.67.95.98
# Connecting to thor.robots.ox.ac.uk (thor.robots.ox.ac.uk)|129.67.95.98|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://thor.robots.ox.ac.uk/datasets/pets/images.tar.gz [following]
# --2024-02-04 12:06:56--  https://thor.robots.ox.ac.uk/datasets/pets/images.tar.gz
# Reusing existing connection to thor.robots.ox.ac.uk:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 791918971 (755M) [application/octet-stream]
# Saving to: ‘images.tar.gz.5’
#
# images.tar.gz.5     100%[===================>] 755.23M  20.6MB/s    in 38s
#
# 2024-02-04 12:07:34 (20.1 MB/s) - ‘images.tar.gz.5’ saved [791918971/791918971]
#
# URL transformed to HTTPS due to an HSTS policy
# --2024-02-04 12:07:34--  https://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz
# Resolving www.robots.ox.ac.uk (www.robots.ox.ac.uk)... 129.67.94.2
# Connecting to www.robots.ox.ac.uk (www.robots.ox.ac.uk)|129.67.94.2|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://thor.robots.ox.ac.uk/~vgg/data/pets/annotations.tar.gz [following]
# --2024-02-04 12:07:34--  https://thor.robots.ox.ac.uk/~vgg/data/pets/annotations.tar.gz
# Resolving thor.robots.ox.ac.uk (thor.robots.ox.ac.uk)... 129.67.95.98
# Connecting to thor.robots.ox.ac.uk (thor.robots.ox.ac.uk)|129.67.95.98|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://thor.robots.ox.ac.uk/datasets/pets/annotations.tar.gz [following]
# --2024-02-04 12:07:35--  https://thor.robots.ox.ac.uk/datasets/pets/annotations.tar.gz
# Reusing existing connection to thor.robots.ox.ac.uk:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 19173078 (18M) [application/octet-stream]
# Saving to: ‘annotations.tar.gz.4’
#
# annotations.tar.gz. 100%[===================>]  18.28M  11.0MB/s    in 1.7s
#
# 2024-02-04 12:07:37 (11.0 MB/s) - ‘annotations.tar.gz.4’ saved [19173078/19173078]

# %%
# !pip install -q git+https://github.com/tensorflow/examples.git
# Out:
#   Preparing metadata (setup.py) ... done

# %%
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_datasets as tfds
from tensorflow.keras.utils import array_to_img
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow_examples.models.pix2pix import pix2pix
import numpy as np
import random
from IPython.display import clear_output
import matplotlib.pyplot as plt
import gc

# %% [markdown]
# ## Data Loading

# %%
input_dir = "images/"
target_dir = "annotations/trimaps/"

# Loading Image Paths
input_img_paths = sorted(
    [os.path.join(input_dir, fname)
     for fname in os.listdir(input_dir)
     if fname.endswith(".jpg")])
target_paths = sorted(
    [os.path.join(target_dir, fname)
     for fname in os.listdir(target_dir)
     if fname.endswith(".png") and not fname.startswith(".")])

# %%
# Checking if the Paths loaded correctly
plt.axis("off")
plt.imshow(load_img(input_img_paths[9]))

# %%
# Function for Displaying Masked Image (Segmented Image)
def display_target(target_array):
    normalized_array = (target_array.astype("uint8") - 1) * 127 # Normalizing the Image
    plt.axis("off")
    plt.imshow(normalized_array[:, :, 0])

img = img_to_array(load_img(target_paths[9], color_mode="grayscale")) # Loading a single image
display_target(img)

# %%
# Loading entire Dataset
img_size = (200, 200) # set it as 200x200 ka tuple
num_imgs = len(input_img_paths)

random.Random(63).shuffle(input_img_paths) # Shuffle the Paths (input_img_paths and target_paths)
random.Random(90).shuffle(target_paths)

# Create function to load input image from path
def path_to_input_image(path):
    return img_to_array(load_img(path, target_size=img_size))

# Create function to load target image from path
def path_to_target(path):
    img = (img_to_array(load_img(path, target_size=img_size, color_mode="grayscale"))).astype('uint8')-1
    return img

input_imgs = np.zeros((num_imgs,) + img_size + (3,), dtype="float32")
targets = np.zeros((num_imgs,) + img_size + (1,), dtype="uint8")
for i in range(num_imgs):
    input_imgs[i] = path_to_input_image(input_img_paths[i])
    targets[i] = path_to_target(target_paths[i])

num_val_samples = 1000 # Play around with it if want to
train_input_imgs = input_imgs[:-num_val_samples]
train_targets = targets[:-num_val_samples]
val_input_imgs = input_imgs[-num_val_samples:]
val_targets = targets[-num_val_samples:]

# %% [markdown]
# ## Model
#
# A Image Segmentation Model, at its core, typically comprises a convolutional neural network (CNN) architecture, leveraging its ability to capture hierarchical features in an image. The model consists of encoder or Downsampler and decoder or Upsampler components, where the encoder extracts relevant features from the input image, and the decoder reconstructs the segmented output.
#
# Each Conv2D layer in the encoder applies filters to the input image, extracting low-level to high-level features. As you move deeper into the encoder, the spatial dimensions of the feature maps typically decrease while the depth (number of channels) increases.
#
# Conv2DTranspose layers are employed in the decoder to upsample the feature maps, gradually increasing the spatial dimensions while reducing the number of channels. Skip connections are often added between corresponding encoder and decoder layers to preserve fine-grained details.

# %%
def get_model(img_size, num_classes):
    inputs = keras.Input(shape=img_size + (3,))
    x = layers.Rescaling(1.0/255)(inputs) # Create a Rescaling layer to convert the range [0,255] to [0,1]

    # Similarly add 6 Conv2D Layers with Relu Activation, Strides as required in alternate layers (for layers with even index) (Try khudse) and padding so that output size is equal to input size.
    # This Block acts as our Encoder Block to understand features of the Input Image
    filters=32
    for i in range(6):
      stride=1
      if i%2==0:
        filters*=2
        stride=2
      x = layers.Conv2D(filters, kernel_size=3, activation='relu', strides=stride, padding='same')(x)

    # Now add 6 Conv2DTranspose Layers with Relu, strides in alternate layers (for layers with odd indexes) and same padding.
    '''This Block acts as our Decoder Block to regenerate the Image from the Convoluted Feature Map. This allows for linking and expanding
    the Segmented Features to the original Image.'''
    filters=512
    for i in range(6):
      filters=filters/2 if i%2==0 else filters
      stride=2 if i%2!=0 else 1
      x = layers.Conv2DTranspose(filters, kernel_size=3, activation='relu', strides=stride, padding='same')(x)

    # Finally, add a softmax with same padding to get the final Segmented Image
    outputs = layers.Conv2D(num_classes, 3, activation="softmax", padding="same")(x)

    # Create the Model using the Model API
    model = keras.Model(inputs, outputs)
    return model

model = get_model(img_size=img_size, num_classes=3) # Why num_classes = 3 here? Batao Sochke
# because we are segregating pixels into 3 classes , pet , its borders and things other than pet as mentioned above
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 200, 200, 3)]     0
#
#  rescaling (Rescaling)       (None, 200, 200, 3)       0
#
#  conv2d (Conv2D)             (None, 100, 100, 64)      1792
#
#  conv2d_1 (Conv2D)           (None, 100, 100, 64)      36928
#
#  conv2d_2 (Conv2D)           (None, 50, 50, 128)       73856
#
#  conv2d_3 (Conv2D)           (None, 50, 50, 128)       147584
#
#  conv2d_4 (Conv2D)           (None, 25, 25, 256)       295168
#
#  conv2d_5 (Conv2D)           (None, 25, 25, 256)       590080
#
#  conv2d_transpose (Conv2DTr  (None, 25, 25, 256)       590080
#  anspose)
#
#  conv2d_transpose_1 (Conv2D  (None, 50, 50, 256)       590080
#  Transpose)
#
#  conv2d_transpose_2 (Conv2D  (None, 50, 50, 128)       295040
#  Transpose)
#
#  conv2d_transpose_3 (Conv2D  (None, 100, 100, 128)     147584
#  Transpose)
#
#  conv2d_transpose_4 (Conv2D  (None, 100, 100, 64)      73792
#  Transpose)
#
#  conv2d_transpose_5 (Conv2D  (None, 200, 200, 64)      36928
#  Transpose)
#
#  conv2d_6 (Conv2D)           (None, 200, 200, 3)       1731
#
# =================================================================
# Total params: 2880643 (10.99 MB)
# Trainable params: 2880643 (10.99 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"]) # Use appropriate Loss function (Hint: Images use kar rhe hai toh konsa use hoga?)
# Callbacks: https://keras.io/api/callbacks/
# We are saving this model after each epoch so that bichme agar band hogaya toh bhi we have somewhere to start with
callbacks = [
    keras.callbacks.ModelCheckpoint("oxford_segmentation.x",
                                    save_best_only=True, verbose=2)
]

# %% [markdown]
# ## Training and Testing

# %%
# Train the Model for 3 epochs with the batch size of 64, make sure to set the callbacks parameter
# 3 epochs se jyda kiya toh Colab Crash hota sadly.. if you wanna do more, try kaggle pe ya locally
history = model.fit(train_input_imgs, train_targets,
                    epochs=3,
                    callbacks=callbacks,
                    batch_size=64,
                    validation_data=(val_input_imgs, val_targets))
# Out:
# Epoch 1/3
# 100/100 [==============================] - ETA: 0s - loss: 0.9546 - accuracy: 0.5720
# Epoch 1: val_loss improved from inf to 0.84872, saving model to oxford_segmentation.x
# 100/100 [==============================] - 121s 927ms/step - loss: 0.9546 - accuracy: 0.5720 - val_loss: 0.8487 - val_accuracy: 0.5715
# Epoch 2/3
# 100/100 [==============================] - ETA: 0s - loss: 0.8119 - accuracy: 0.6358
# Epoch 2: val_loss improved from 0.84872 to 0.80621, saving model to oxford_segmentation.x
# 100/100 [==============================] - 65s 650ms/step - loss: 0.8119 - accuracy: 0.6358 - val_loss: 0.8062 - val_accuracy: 0.6655
# Epoch 3/3
# 100/100 [==============================] - ETA: 0s - loss: 0.7931 - accuracy: 0.6668
# Epoch 3: val_loss improved from 0.80621 to 0.80150, saving model to oxford_segmentation.x
# 100/100 [==============================] - 67s 670ms/step - loss: 0.7931 - accuracy: 0.6668 - val_loss: 0.8015 - val_accuracy: 0.6675

# %%
# Plotting Loss
epochs = range(1, len(history.history["loss"]) + 1)
loss = history.history["loss"] # history me se Loss nikalo
val_loss = history.history["val_loss"] # history me se validation loss nikalo
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()

# %%
tf.keras.backend.clear_session()

# %%
from tensorflow.keras.models import load_model
# Load the Saved Model using load_model
model = keras.models.load_model("oxford_segmentation.x")

# %%
# Test Model
def predict(i):
  test_image = val_input_imgs[i:i+1]
  test_image=np.squeeze(test_image,axis=0)
  plt.axis("off")
  plt.imshow(array_to_img(test_image))
  mask = model.predict(np.expand_dims(test_image, 0))[0] # Predict karo. PS: Look carefully at the dimensions.
  display_mask(mask)

def display_mask(pred):
    mask = np.argmax(pred, axis=-1)
    mask *= 127
    plt.axis("off")
    plt.imshow(mask)

# Use or Modify the above Functions to display 20 test images in the SAME PLOT
plt.figure(figsize=(20, 10))
for i in range(20):
    plt.subplot(4, 5, i + 1)  # Create a subplot for each image
    predict(i)

plt.show()
# Out:
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step

# %%
# Garbage Collection so that aage wale parts me issue nhi aaye
del(model,train_input_imgs, train_targets, val_input_imgs, val_targets, history, input_imgs, targets)
gc.collect()
# Out:
# 43633

# %% [markdown]
# ## Image Segmentation using Transfer Learning and Existing Architectures

# %% [markdown]
# So now, we implemented a Custom Model for Image Segmentation. Abhi there are a few existing architectures which efficiently do this for us. For example: U-Net, Mask R-CNN, Fast FCN etc.
#
# You can read more about them here:
# https://neptune.ai/blog/image-segmentation#:~:text=The%20basic%20architecture%20in%20image,an%20encoder%20and%20a%20decoder.&text=The%20encoder%20extracts%20features%20from,the%20outline%20of%20the%20object.
#
#
#
# We will now implement U-Net Architecture. It is similar to the one we created above.
# https://www.geeksforgeeks.org/u-net-architecture-explained/

# %% [markdown]
# ## Data Loading

# %%
dataset, info = tfds.load('oxford_iiit_pet:3.*.*', with_info=True)
# Out:
# Downloading and preparing dataset 773.52 MiB (download: 773.52 MiB, generated: 774.69 MiB, total: 1.51 GiB) to /root/tensorflow_datasets/oxford_iiit_pet/3.2.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/3680 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/oxford_iiit_pet/3.2.0.incomplete8AGQPG/oxford_iiit_pet-train.tfrecord*...:…
# Generating test examples...:   0%|          | 0/3669 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/oxford_iiit_pet/3.2.0.incomplete8AGQPG/oxford_iiit_pet-test.tfrecord*...: …
# Dataset oxford_iiit_pet downloaded and prepared to /root/tensorflow_datasets/oxford_iiit_pet/3.2.0. Subsequent calls will reuse this data.

# %%
dataset
# Out:
# {'train': <_PrefetchDataset element_spec={'file_name': TensorSpec(shape=(), dtype=tf.string, name=None), 'image': TensorSpec(shape=(None, None, 3), dtype=tf.uint8, name=None), 'label': TensorSpec(shape=(), dtype=tf.int64, name=None), 'segmentation_mask': TensorSpec(shape=(None, None, 1), dtype=tf.uint8, name=None), 'species': TensorSpec(shape=(), dtype=tf.int64, name=None)}>,
#  'test': <_PrefetchDataset element_spec={'file_name': TensorSpec(shape=(), dtype=tf.string, name=None), 'image': TensorSpec(shape=(None, None, 3), dtype=tf.uint8, name=None), 'label': TensorSpec(shape=(), dtype=tf.int64, name=None), 'segmentation_mask': TensorSpec(shape=(None, None, 1), dtype=tf.uint8, name=None), 'species': TensorSpec(shape=(), dtype=tf.int64, name=None)}>}

# %%
def normalize(input_image, input_mask):
  input_image = tf.cast(input_image, tf.float32) / 255.0
  input_mask -= 1
  return input_image, input_mask

# %%
def load_image(datapoint):
  input_image = tf.image.resize(datapoint["image"],(128,128)) # Use tf.image to resize datapoint["image"] to (128,128)
  input_mask = tf.image.resize(datapoint["segmentation_mask"],(128,128),method=tf.image.ResizeMethod.NEAREST_NEIGHBOR) # Use Nearest Neighbour Method to resize datapoint["segmentation_mask"] to (128,128) for the image mask
  input_image, input_mask = normalize(input_image,input_mask) # Normalize the Images

  return input_image, input_mask

# %% [markdown]
# The dataset already contains the required training and test splits, so continue to use the same splits:

# %%
TRAIN_LENGTH = info.splits['train'].num_examples
BATCH_SIZE = 64
BUFFER_SIZE = 1000
STEPS_PER_EPOCH = TRAIN_LENGTH // BATCH_SIZE

# %%
train_images = dataset['train'].map(load_image, num_parallel_calls=tf.data.AUTOTUNE)
test_images = dataset['test'].map(load_image, num_parallel_calls=tf.data.AUTOTUNE)

# %% [markdown]
# The following class performs a simple augmentation by randomly-flipping an image.
#
# [Image augmentation](https://www.tensorflow.org/tutorials/images/data_augmentation)

# %%
class Augment(tf.keras.layers.Layer):
  def __init__(self, seed=42):
    super().__init__()
    # both use the same seed, so they'll make the same random changes.
    self.augment_inputs = tf.keras.layers.RandomFlip(mode="horizontal", seed=seed)
    self.augment_labels = tf.keras.layers.RandomFlip(mode="horizontal", seed=seed)# Do the same for this

  def call(self, inputs, labels):
    inputs = self.augment_inputs(inputs)
    labels = self.augment_labels(labels)
    return inputs, labels

# %% [markdown]
# Build the input pipeline, applying the augmentation after batching the inputs:

# %%
train_batches = (
    train_images
    .cache()
    .shuffle(BUFFER_SIZE)
    .batch(BATCH_SIZE)
    .repeat()
    .map(Augment())
    .prefetch(buffer_size=tf.data.AUTOTUNE)) # Prefetch is an important step towards training efficiency as it allows the Model to Fetch the Next Batch of Data while Training on a Different Batch
    # AUTOTUNE allows Tensorflow to automatically adjust the prefetch buffer. Use that.

test_batches = test_images.batch(BATCH_SIZE)

# %% [markdown]
# Visualize an image example and its corresponding mask from the dataset:

# %%
def display(display_list):
  plt.figure(figsize=(15, 15))

  title = ['Input Image', 'True Mask', 'Predicted Mask']

  for i in range(len(display_list)):
    plt.subplot(1, len(display_list), i+1)
    plt.title(title[i])
    plt.imshow(tf.keras.utils.array_to_img(display_list[i]))
    plt.axis('off')
  plt.show()

# %%
# Use the train_batches to obtain 2 images and display them using the function above
example_batch = next(iter(train_batches))
image_batch, mask_batch = example_batch
display([image_batch[0], mask_batch[0]])
display([image_batch[1], mask_batch[1]])

# %% [markdown]
# ## Define the model
#
# The model being used here is a modified [U-Net](https://arxiv.org/abs/1505.04597). A U-Net consists of an encoder (downsampler) and decoder (upsampler). To learn robust features and reduce the number of trainable parameters, use a pretrained model—[MobileNetV2](https://arxiv.org/abs/1801.04381)—as the encoder. For the decoder, you will use the upsample block, which is already implemented in the [pix2pix](https://github.com/tensorflow/examples/blob/master/tensorflow_examples/models/pix2pix/pix2pix.py) example in the TensorFlow Examples repo.

# %% [markdown]
# As mentioned, the encoder is a pretrained MobileNetV2 model. You will use the model from `tf.keras.applications`. The encoder consists of specific outputs from intermediate layers in the model. Note that the encoder will not be trained during the training process.

# %%
base_model = tf.keras.applications.MobileNetV2(input_shape=[128,128,3],include_top=False)# Load the MobileNetV2 Pre-trained model without its final Dense Layers with input_shape=[128, 128, 3]

# Use the activations of these layers
layer_names = [
    'block_1_expand_relu',   # 64x64
    'block_3_expand_relu',   # 32x32
    'block_6_expand_relu',   # 16x16
    'block_13_expand_relu',  # 8x8
    'block_16_project',      # 4x4
]
base_model_outputs = [base_model.get_layer(name).output for name in layer_names]

# Create the feature extraction model using the tf.keras.Model
down_stack = tf.keras.Model(inputs=base_model.input,outputs=base_model_outputs)

# Since this acts as our pre-trained encoder block, make sure to set the layers to be non-trainable
down_stack.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_128_no_top.h5
# 9406464/9406464 [==============================] - 0s 0us/step

# %% [markdown]
# The decoder/upsampler is simply a series of upsample blocks implemented in TensorFlow examples:

# %%
# Use pix2pix upsample layers to get our unsampling block
up_stack = [
    pix2pix.upsample(512, 3),  # 4x4 -> 8x8
    pix2pix.upsample(256, 3),  # 8x8 -> 16x16
    pix2pix.upsample(128, 3),  # 16x16 -> 32x32
    pix2pix.upsample(64, 3),   # 32x32 -> 64x64
]

# %%
def unet_model(output_channels:int):
  inputs = tf.keras.layers.Input(shape=[128,128,3])# Create an Input Layer of shape (128,128,3)

  # Downsampling through the model
  skips = down_stack(inputs)
  x = skips[-1]
  skips = reversed(skips[:-1])

  # Upsampling and establishing the skip connections
  for up, skip in zip(up_stack, skips):
    x = up(x)
    concat = tf.keras.layers.Concatenate()# Concatenate X and Skip Layers
    x = concat([x,skip])

  # This is the last layer of the model
  last = tf.keras.layers.Conv2DTranspose(
      filters=output_channels, kernel_size=3, strides=2,
      padding='same')  #64x64 -> 128x128

  x = last(x)

  return tf.keras.Model(inputs=inputs, outputs=x)

# %% [markdown]
# Note that the number of filters on the last layer is set to the number of `output_channels`. This will be one output channel per class.

# %% [markdown]
# ## Train the model
#
# Now, all that is left to do is to compile and train the model.
#
# When running inference, the label assigned to the pixel is the channel with the highest value. This is what the `create_mask` function is doing.

# %%
OUTPUT_CLASSES = 3

model = unet_model(output_channels=OUTPUT_CLASSES)
model.compile( optimizer='adam',loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),# Use Adam with the appropraite Loss. PS: We are using scalar integers as labels.. toh kuch change aayega loss me
              metrics=['accuracy'])

# %% [markdown]
# Plot the resulting model architecture:

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 128, 128, 3)]        0         []
#
#  model (Functional)          [(None, 64, 64, 96),         1841984   ['input_3[0][0]']
#                               (None, 32, 32, 144),
#                               (None, 16, 16, 192),
#                               (None, 8, 8, 576),
#                               (None, 4, 4, 320)]
#
#  sequential (Sequential)     (None, 8, 8, 512)            1476608   ['model[1][4]']
#
#  concatenate_4 (Concatenate  (None, 8, 8, 1088)           0         ['sequential[1][0]',
#  )                                                                   'model[1][3]']
#
#  sequential_1 (Sequential)   (None, 16, 16, 256)          2507776   ['concatenate_4[0][0]']
#
#  concatenate_5 (Concatenate  (None, 16, 16, 448)          0         ['sequential_1[1][0]',
#  )                                                                   'model[1][2]']
#
#  sequential_2 (Sequential)   (None, 32, 32, 128)          516608    ['concatenate_5[0][0]']
#
#  concatenate_6 (Concatenate  (None, 32, 32, 272)          0         ['sequential_2[1][0]',
#  )                                                                   'model[1][1]']
#
#  sequential_3 (Sequential)   (None, 64, 64, 64)           156928    ['concatenate_6[0][0]']
#
#  concatenate_7 (Concatenate  (None, 64, 64, 160)          0         ['sequential_3[1][0]',
#  )                                                                   'model[1][0]']
#
#  conv2d_transpose_5 (Conv2D  (None, 128, 128, 3)          4323      ['concatenate_7[0][0]']
#  Transpose)
#
# ==================================================================================================
# Total params: 6504227 (24.81 MB)
# Trainable params: 4660323 (17.78 MB)
# Non-trainable params: 1843904 (7.03 MB)
# __________________________________________________________________________________________________

# %% [markdown]
# Try out the model to check what it predicts before training:

# %%
def create_mask(pred_mask):
  pred_mask = tf.math.argmax(pred_mask, axis=-1)
  pred_mask = pred_mask[..., tf.newaxis]
  return pred_mask[0]

# %%
def show_predictions(dataset=None, num=1):
  if dataset:
    for image, mask in dataset.take(num):
      pred_mask = model.predict(image)
      display([image[0], mask[0], create_mask(pred_mask)])
  else:
    display([image_batch[0], mask_batch[0],
             create_mask(model.predict(image_batch[0][tf.newaxis, ...]))])

# %%
show_predictions()
# Out:
# 1/1 [==============================] - 3s 3s/step

# %% [markdown]
# The callback defined below is used to observe how the model improves while it is training:

# %%
class DisplayCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs=None):
    clear_output(wait=True)
    show_predictions()
    print ('\nSample Prediction after epoch {}\n'.format(epoch+1))

# %% [markdown]
# In the interest of saving time, the number of epochs was kept small, but you may set this higher to achieve more accurate results.

# %%
EPOCHS = 20
VAL_SUBSPLITS = 5
VALIDATION_STEPS = info.splits['test'].num_examples//BATCH_SIZE//VAL_SUBSPLITS

model_history = model.fit(train_batches, epochs=EPOCHS,
                          steps_per_epoch=STEPS_PER_EPOCH,
                          validation_steps=VALIDATION_STEPS,
                          validation_data=test_batches,
                          callbacks=[DisplayCallback()])
# Out:
# 1/1 [==============================] - 0s 22ms/step
# Sample Prediction after epoch 20
#
# 57/57 [==============================] - 13s 222ms/step - loss: 0.1720 - accuracy: 0.9297 - val_loss: 0.2723 - val_accuracy: 0.9023

# %%
# Plot Loss and Validation Loss as previously done
loss = model_history.history["loss"] # history me se Loss nikalo
val_loss = model_history.history["val_loss"] # history me se validation loss nikalo
plt.figure()
plt.plot(model_history.epoch, loss, "bo", label="Training loss")
plt.plot(model_history.epoch, val_loss, "g", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()

# %% [markdown]
# ## Make predictions

# %% [markdown]
# Now, make some predictions.

# %%
show_predictions(test_batches, 3)
# Out:
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 41ms/step

# %% [markdown]
# ## OPTIONAL: Image Segmentation usually involves high class imbalance. Figure out how you can reduce this problem.

# %% [markdown]
# # Object Detection

# %% [markdown]
# Object detection is a computer vision technique for locating instances of objects in images or videos.
#
# Read more:
#
# https://www.mathworks.com/discovery/object-detection.html
#
# https://www.analyticsvidhya.com/blog/2022/03/a-basic-introduction-to-object-detection/

# %% [markdown]
# In this, we will not use one of those high performing off-the-shelf object detectors but develop a new one ourselves, from scratch, using plain python, OpenCV, and Tensorflow.
#
# An Object Detection is a combination of two tasks:
# *   Regression of the bound-box coordinates
# *   Classification of the object label
#
# This means that our model has two outputs: namely the object label and the object bound box. Therefore, the model must combine the tasks of classification and regression.

# %% [markdown]
# The Dataset we will be using is:
#
# https://www.kaggle.com/datasets/techzizou/labeled-mask-dataset-yolo-darknet
#
# Drive pe daaldena

# %% [markdown]
# ## Imports

# %%
import os, random
from google.colab import drive
import tensorflow as tf
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Data Loading

# %% [markdown]
# This code basically generates three lists: one for training (holding 70% of the data), one for validation (20% of the data) and one for test (the last 10%). The code also shuffle the data in order to avoid any natural bias.
#
# Note that we are removing the images with more than one masks/objects. This is because we are building a simple object detector able to detect only a single object in an image.

# %%
def list_files(full_data_path = "/content/gdrive/My Drive/obj/", image_ext = '.jpg', split_percentage = [70, 20]):

    files = []

    discarded = 0
    masked_instance = 0

    for r, d, f in os.walk(full_data_path):
        for file in f:
            if file.endswith(".txt"):

                # first, let's check if there is only one object
                with open(full_data_path + "/" + file, 'r') as fp:
                    lines = fp.readlines()
                    if len(lines) > 1:
                        discarded += 1
                        continue


                strip = file[0:len(file) - len(".txt")]
                # secondly, check if the paired image actually exist
                image_path = full_data_path + "/" + strip + image_ext
                if os.path.isfile(image_path):
                    # checking the class. '0' means masked, '1' for unmasked
                    if lines[0][0] == '0':
                        masked_instance += 1
                    files.append(strip)

    size = len(files)
    print(str(discarded) + " file(s) discarded")
    print(str(size) + " valid case(s)")
    print(str(masked_instance) + " are masked cases")

    random.shuffle(files)

    split_training = int(split_percentage[0] * size / 100)
    split_validation = split_training + int(split_percentage[1] * size / 100)

    return files[0:split_training], files[split_training:split_validation], files[split_validation:]

training_files, validation_files, test_files = list_files()
# Out:
# 223 file(s) discarded
# 1292 valid case(s)
# 832 are masked cases

# %%
print(str(len(training_files)) + " training files")
print(str(len(validation_files)) + " validation files")
print(str(len(test_files)) + " test files")
# Out:
# 904 training files
# 258 validation files
# 130 test files

# %% [markdown]
# Since our model will be using a fixed 244 x 244 input layer, we need to format any input image before feed it to the model (to train or to predict).

# %%
input_size = 244

def format_image(img, box):
  '''
  1. Get the height and width of the input image.
  2. Calculate the maximum dimension of the image (either height or width).
  3. Calculate the scaling ratio needed to fit the image within the desired input_size.
  4. Calculate the new width and height of the image based on the scaling ratio.
  5. Create a tuple new_size containing the new width and height.
  6. Resize the original image to the new dimensions using linear interpolation.
  7. Create a new image (new_image) of size input_size x input_size initialized with zeros.
  8. Place the resized image in the upper-left corner of new_image, filling the remaining space with zeros.
  '''
  height, width = img.shape[:2]
  max_dim = max(height, width)

  scaling_ratio = max_dim/input_size
  new_height = int(height/scaling_ratio)
  new_width = int(width/scaling_ratio)
  new_size = (new_width, new_height)
  resized_img = cv.resize(img, new_size, interpolation=cv.INTER_LINEAR)
  new_image = np.zeros((input_size, input_size),dtype=np.uint8)
  new_image[0:new_height, 0:new_width] = resized_img
  x, y, w, h = box[0], box[1], box[2], box[3]


  # Calculate the new coordinates and dimensions (new_box) based on the scaling ratio (r)
  new_box=[int((x-0.5*w)*width /scaling_ratio), int((y-0.5*h)*height /scaling_ratio), int(w*width /scaling_ratio), int(h*height /scaling_ratio)]

  return new_image, new_box

# %%
def data_load(files, full_data_path = "/content/gdrive/My Drive/obj/", image_ext = ".jpg"):
    X = []
    Y = []

    for file in files:
        img = cv.imread(os.path.join(full_data_path, file + image_ext), cv.IMREAD_GRAYSCALE)

        k = 1

        with open(full_data_path + "/" + file + ".txt", 'r') as fp:
            line = fp.readlines()[0]
            if line[0] == '0':
                k = 0

            box = np.array(line[1:].split(), dtype=float)

        img, box = format_image(img, box)
        img = img.astype(float) / 255.
        box = np.asarray(box, dtype=float) / input_size
        label = np.append(box, k)

        X.append(img)
        Y.append(label)

    X = np.array(X)

    X = np.expand_dims(X, axis=3)

    X =tf.convert_to_tensor(X,dtype=tf.float32) # Convert X and Y to tensors with dtype as float32

    Y =tf.convert_to_tensor(Y,dtype=tf.float32)

    result = tf.data.Dataset.from_tensor_slices((X, Y))

    return result

# %%
raw_train_ds = data_load(training_files)

# %%
raw_validation_ds = data_load(validation_files)

# %%
raw_test_ds = data_load(test_files)

# %% [markdown]
# Since our model must implement two tasks — classification and regression — we need two different Loss Functions:
#
# * One for the classification task: we may use any Loss Function usually found in only-classification tasks like Categorical Crossentropy.
# * One for the bound box regression: we can use a regression Loss Function such as Mean Squared Error.

# %%
CLASSES = 2

def format_instance(image, label):
    return image, (tf.one_hot(int(label[4]), CLASSES), [label[0], label[1], label[2], label[3]])

# %%
BATCH_SIZE = 32

# see https://www.tensorflow.org/guide/data_performance

def tune_training_ds(dataset):
    dataset = dataset.map(format_instance, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.shuffle(1024, reshuffle_each_iteration=True)
    dataset = dataset.repeat() # The dataset be repeated indefinitely.
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset

# %%
train_ds = tune_training_ds(raw_train_ds)

# %%
def tune_validation_ds(dataset):
    dataset = dataset.map(format_instance, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.batch(len(validation_files) // 4)
    dataset = dataset.repeat()
    return dataset

# %%
validation_ds = tune_validation_ds(raw_validation_ds)

# %%
def tune_test_ds(dataset):
    dataset = dataset.map(format_instance, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.batch(1)
    dataset = dataset.repeat()
    return dataset

test_ds = tune_test_ds(raw_test_ds)

# %% [markdown]
# ## Model

# %%
def build_feature_extractor(inputs):
    # use 3 pairs of Conv2D and AveragePooling2D with relu activation and kernel size = 3. Keep in mind we will be using
    x= tf.keras.layers.Conv2D(32,kernel_size=3,activation='relu',input_shape=(input_size,input_size,1))(inputs)
    x= tf.keras.layers.AveragePooling2D(4,4)(x)
    x= tf.keras.layers.Conv2D(64,kernel_size=3,activation='relu')(x)
    x= tf.keras.layers.AveragePooling2D(4,4)(x)
    x= tf.keras.layers.Conv2D(128,kernel_size=3,activation='relu')(x)
    x= tf.keras.layers.AveragePooling2D(4,4)(x)
    return x

def build_model_adaptor(inputs):
    # Use one Flatten and One Dense Relu Layer
    x= tf.keras.layers.Flatten()(inputs)
    x= tf.keras.layers.Dense(128,activation='relu')(x)
    return x

def build_classifier_head(inputs):
    # use a Softmax Layer named classifier_head
    x= tf.keras.layers.Dense(CLASSES,activation='softmax',name='classifier_head')(inputs)
    return x

def build_regressor_head(inputs):
    # use a Dense layer with 4 units named regressor_head
    x= tf.keras.layers.Dense(units='4',name='regressor_head')(inputs)
    return x

def build_model(inputs):

    feature_extractor = build_feature_extractor(inputs)

    model_adaptor = build_model_adaptor(feature_extractor)

    classification_head = build_classifier_head(model_adaptor)

    regressor_head = build_regressor_head(model_adaptor)

    model = tf.keras.Model(inputs = inputs, outputs = [classification_head, regressor_head])

    return model

# %% [markdown]
# Now that we have everything, Let's start with training!

# %% [markdown]
# ## Training

# %%
model = build_model(tf.keras.layers.Input(shape=(input_size, input_size, 1,)))

model.compile(optimizer='adam',loss={'classifier_head':'categorical_crossentropy','regressor_head':'mse'},
              metrics={'classifier_head':'accuracy','regressor_head':'mse'})# Use Adam and set loss and metric for classifier_head and regressor_head as stated earlier

# %%
# Plot the Model
tf.keras.utils.plot_model(model)

# %%
EPOCHS = 100
BATCH_SIZE = 32

history = model.fit(train_ds,
                    steps_per_epoch=(len(training_files) // BATCH_SIZE),
                    validation_data=validation_ds, validation_steps=1,
                    epochs=EPOCHS)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 6s 64ms/step - loss: 0.6686 - classifier_head_loss: 0.6369 - regressor_head_loss: 0.0318 - classifier_head_accuracy: 0.6295 - regressor_head_mse: 0.0318 - val_loss: 0.5836 - val_classifier_head_loss: 0.5693 - val_regressor_head_loss: 0.0143 - val_classifier_head_accuracy: 0.7031 - val_regressor_head_mse: 0.0143
# Epoch 2/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.6101 - classifier_head_loss: 0.5961 - regressor_head_loss: 0.0140 - classifier_head_accuracy: 0.6406 - regressor_head_mse: 0.0140 - val_loss: 0.6028 - val_classifier_head_loss: 0.5905 - val_regressor_head_loss: 0.0123 - val_classifier_head_accuracy: 0.7031 - val_regressor_head_mse: 0.0123
# Epoch 3/100
# 28/28 [==============================] - 1s 34ms/step - loss: 0.5972 - classifier_head_loss: 0.5825 - regressor_head_loss: 0.0148 - classifier_head_accuracy: 0.6708 - regressor_head_mse: 0.0148 - val_loss: 0.5852 - val_classifier_head_loss: 0.5720 - val_regressor_head_loss: 0.0132 - val_classifier_head_accuracy: 0.7969 - val_regressor_head_mse: 0.0132
# Epoch 4/100
# 28/28 [==============================] - 1s 35ms/step - loss: 0.5612 - classifier_head_loss: 0.5464 - regressor_head_loss: 0.0148 - classifier_head_accuracy: 0.7377 - regressor_head_mse: 0.0148 - val_loss: 0.5061 - val_classifier_head_loss: 0.4932 - val_regressor_head_loss: 0.0129 - val_classifier_head_accuracy: 0.7812 - val_regressor_head_mse: 0.0129
# Epoch 5/100
# 28/28 [==============================] - 1s 34ms/step - loss: 0.5255 - classifier_head_loss: 0.5085 - regressor_head_loss: 0.0170 - classifier_head_accuracy: 0.7801 - regressor_head_mse: 0.0170 - val_loss: 0.4908 - val_classifier_head_loss: 0.4770 - val_regressor_head_loss: 0.0137 - val_classifier_head_accuracy: 0.8594 - val_regressor_head_mse: 0.0137
# Epoch 6/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.4620 - classifier_head_loss: 0.4461 - regressor_head_loss: 0.0159 - classifier_head_accuracy: 0.8092 - regressor_head_mse: 0.0159 - val_loss: 0.4113 - val_classifier_head_loss: 0.3882 - val_regressor_head_loss: 0.0231 - val_classifier_head_accuracy: 0.8750 - val_regressor_head_mse: 0.0231
# Epoch 7/100
# 28/28 [==============================] - 1s 27ms/step - loss: 0.4065 - classifier_head_loss: 0.3919 - regressor_head_loss: 0.0146 - classifier_head_accuracy: 0.8415 - regressor_head_mse: 0.0146 - val_loss: 0.3593 - val_classifier_head_loss: 0.3474 - val_regressor_head_loss: 0.0119 - val_classifier_head_accuracy: 0.8750 - val_regressor_head_mse: 0.0119
# Epoch 8/100
# 28/28 [==============================] - 1s 25ms/step - loss: 0.3835 - classifier_head_loss: 0.3697 - regressor_head_loss: 0.0139 - classifier_head_accuracy: 0.8504 - regressor_head_mse: 0.0139 - val_loss: 0.3560 - val_classifier_head_loss: 0.3413 - val_regressor_head_loss: 0.0148 - val_classifier_head_accuracy: 0.8906 - val_regressor_head_mse: 0.0148
# Epoch 9/100
# 28/28 [==============================] - 1s 27ms/step - loss: 0.3428 - classifier_head_loss: 0.3302 - regressor_head_loss: 0.0125 - classifier_head_accuracy: 0.8705 - regressor_head_mse: 0.0125 - val_loss: 0.3264 - val_classifier_head_loss: 0.3152 - val_regressor_head_loss: 0.0112 - val_classifier_head_accuracy: 0.8750 - val_regressor_head_mse: 0.0112
# Epoch 10/100
# 28/28 [==============================] - 1s 27ms/step - loss: 0.3174 - classifier_head_loss: 0.3072 - regressor_head_loss: 0.0102 - classifier_head_accuracy: 0.8728 - regressor_head_mse: 0.0102 - val_loss: 0.2816 - val_classifier_head_loss: 0.2668 - val_regressor_head_loss: 0.0148 - val_classifier_head_accuracy: 0.8750 - val_regressor_head_mse: 0.0148
# Epoch 11/100
# 28/28 [==============================] - 1s 26ms/step - loss: 0.2958 - classifier_head_loss: 0.2833 - regressor_head_loss: 0.0124 - classifier_head_accuracy: 0.8828 - regressor_head_mse: 0.0124 - val_loss: 0.2839 - val_classifier_head_loss: 0.2715 - val_regressor_head_loss: 0.0124 - val_classifier_head_accuracy: 0.8906 - val_regressor_head_mse: 0.0124
# Epoch 12/100
# 28/28 [==============================] - 1s 25ms/step - loss: 0.2833 - classifier_head_loss: 0.2708 - regressor_head_loss: 0.0125 - classifier_head_accuracy: 0.8929 - regressor_head_mse: 0.0125 - val_loss: 0.3083 - val_classifier_head_loss: 0.2955 - val_regressor_head_loss: 0.0129 - val_classifier_head_accuracy: 0.8438 - val_regressor_head_mse: 0.0129
# Epoch 13/100
# 28/28 [==============================] - 1s 25ms/step - loss: 0.2683 - classifier_head_loss: 0.2562 - regressor_head_loss: 0.0121 - classifier_head_accuracy: 0.9051 - regressor_head_mse: 0.0121 - val_loss: 0.2550 - val_classifier_head_loss: 0.2431 - val_regressor_head_loss: 0.0120 - val_classifier_head_accuracy: 0.8750 - val_regressor_head_mse: 0.0120
# Epoch 14/100
# 28/28 [==============================] - 1s 25ms/step - loss: 0.2535 - classifier_head_loss: 0.2425 - regressor_head_loss: 0.0110 - classifier_head_accuracy: 0.9018 - regressor_head_mse: 0.0110 - val_loss: 0.2848 - val_classifier_head_loss: 0.2713 - val_regressor_head_loss: 0.0135 - val_classifier_head_accuracy: 0.8750 - val_regressor_head_mse: 0.0135
# Epoch 15/100
# 28/28 [==============================] - 1s 25ms/step - loss: 0.2301 - classifier_head_loss: 0.2204 - regressor_head_loss: 0.0097 - classifier_head_accuracy: 0.9174 - regressor_head_mse: 0.0097 - val_loss: 0.2571 - val_classifier_head_loss: 0.2448 - val_regressor_head_loss: 0.0123 - val_classifier_head_accuracy: 0.9062 - val_regressor_head_mse: 0.0123
# Epoch 16/100
# 28/28 [==============================] - 1s 26ms/step - loss: 0.2509 - classifier_head_loss: 0.2397 - regressor_head_loss: 0.0111 - classifier_head_accuracy: 0.9051 - regressor_head_mse: 0.0111 - val_loss: 0.2729 - val_classifier_head_loss: 0.2582 - val_regressor_head_loss: 0.0147 - val_classifier_head_accuracy: 0.9062 - val_regressor_head_mse: 0.0147
# Epoch 17/100
# 28/28 [==============================] - 1s 25ms/step - loss: 0.2082 - classifier_head_loss: 0.1982 - regressor_head_loss: 0.0100 - classifier_head_accuracy: 0.9219 - regressor_head_mse: 0.0100 - val_loss: 0.2294 - val_classifier_head_loss: 0.2195 - val_regressor_head_loss: 0.0099 - val_classifier_head_accuracy: 0.8906 - val_regressor_head_mse: 0.0099
# Epoch 18/100
# 28/28 [==============================] - 1s 26ms/step - loss: 0.2031 - classifier_head_loss: 0.1929 - regressor_head_loss: 0.0101 - classifier_head_accuracy: 0.9230 - regressor_head_mse: 0.0101 - val_loss: 0.2423 - val_classifier_head_loss: 0.2280 - val_regressor_head_loss: 0.0143 - val_classifier_head_accuracy: 0.9062 - val_regressor_head_mse: 0.0143
# Epoch 19/100
# 28/28 [==============================] - 1s 27ms/step - loss: 0.1936 - classifier_head_loss: 0.1833 - regressor_head_loss: 0.0104 - classifier_head_accuracy: 0.9275 - regressor_head_mse: 0.0104 - val_loss: 0.2496 - val_classifier_head_loss: 0.2346 - val_regressor_head_loss: 0.0150 - val_classifier_head_accuracy: 0.8906 - val_regressor_head_mse: 0.0150
# Epoch 20/100
# 28/28 [==============================] - 1s 28ms/step - loss: 0.1970 - classifier_head_loss: 0.1870 - regressor_head_loss: 0.0100 - classifier_head_accuracy: 0.9297 - regressor_head_mse: 0.0100 - val_loss: 0.2685 - val_classifier_head_loss: 0.2564 - val_regressor_head_loss: 0.0121 - val_classifier_head_accuracy: 0.8906 - val_regressor_head_mse: 0.0121
# Epoch 21/100
# 28/28 [==============================] - 1s 33ms/step - loss: 0.1698 - classifier_head_loss: 0.1599 - regressor_head_loss: 0.0099 - classifier_head_accuracy: 0.9442 - regressor_head_mse: 0.0099 - val_loss: 0.2569 - val_classifier_head_loss: 0.2439 - val_regressor_head_loss: 0.0130 - val_classifier_head_accuracy: 0.9062 - val_regressor_head_mse: 0.0130
# Epoch 22/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.1841 - classifier_head_loss: 0.1735 - regressor_head_loss: 0.0107 - classifier_head_accuracy: 0.9286 - regressor_head_mse: 0.0107 - val_loss: 0.2607 - val_classifier_head_loss: 0.2458 - val_regressor_head_loss: 0.0149 - val_classifier_head_accuracy: 0.9062 - val_regressor_head_mse: 0.0149
# Epoch 23/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.1895 - classifier_head_loss: 0.1791 - regressor_head_loss: 0.0104 - classifier_head_accuracy: 0.9364 - regressor_head_mse: 0.0104 - val_loss: 0.2772 - val_classifier_head_loss: 0.2609 - val_regressor_head_loss: 0.0163 - val_classifier_head_accuracy: 0.9062 - val_regressor_head_mse: 0.0163
# Epoch 24/100
# 28/28 [==============================] - 1s 33ms/step - loss: 0.1639 - classifier_head_loss: 0.1532 - regressor_head_loss: 0.0107 - classifier_head_accuracy: 0.9442 - regressor_head_mse: 0.0107 - val_loss: 0.2619 - val_classifier_head_loss: 0.2489 - val_regressor_head_loss: 0.0130 - val_classifier_head_accuracy: 0.8594 - val_regressor_head_mse: 0.0130
# Epoch 25/100
# 28/28 [==============================] - 1s 34ms/step - loss: 0.1634 - classifier_head_loss: 0.1525 - regressor_head_loss: 0.0110 - classifier_head_accuracy: 0.9487 - regressor_head_mse: 0.0110 - val_loss: 0.2008 - val_classifier_head_loss: 0.1884 - val_regressor_head_loss: 0.0124 - val_classifier_head_accuracy: 0.9062 - val_regressor_head_mse: 0.0124
# Epoch 26/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.1153 - classifier_head_loss: 0.1053 - regressor_head_loss: 0.0100 - classifier_head_accuracy: 0.9654 - regressor_head_mse: 0.0100 - val_loss: 0.2595 - val_classifier_head_loss: 0.2468 - val_regressor_head_loss: 0.0127 - val_classifier_head_accuracy: 0.9219 - val_regressor_head_mse: 0.0127
# Epoch 27/100
# 28/28 [==============================] - 1s 27ms/step - loss: 0.1680 - classifier_head_loss: 0.1569 - regressor_head_loss: 0.0111 - classifier_head_accuracy: 0.9308 - regressor_head_mse: 0.0111 - val_loss: 0.2544 - val_classifier_head_loss: 0.2444 - val_regressor_head_loss: 0.0101 - val_classifier_head_accuracy: 0.9219 - val_regressor_head_mse: 0.0101
# Epoch 28/100
# 28/28 [==============================] - 1s 26ms/step - loss: 0.1442 - classifier_head_loss: 0.1346 - regressor_head_loss: 0.0096 - classifier_head_accuracy: 0.9464 - regressor_head_mse: 0.0096 - val_loss: 0.2868 - val_classifier_head_loss: 0.2763 - val_regressor_head_loss: 0.0104 - val_classifier_head_accuracy: 0.8906 - val_regressor_head_mse: 0.0104
# Epoch 29/100
# 28/28 [==============================] - 1s 26ms/step - loss: 0.1172 - classifier_head_loss: 0.1081 - regressor_head_loss: 0.0091 - classifier_head_accuracy: 0.9565 - regressor_head_mse: 0.0091 - val_loss: 0.2045 - val_classifier_head_loss: 0.1934 - val_regressor_head_loss: 0.0111 - val_classifier_head_accuracy: 0.9062 - val_regressor_head_mse: 0.0111
# Epoch 30/100
# 28/28 [==============================] - 1s 25ms/step - loss: 0.1098 - classifier_head_loss: 0.1018 - regressor_head_loss: 0.0081 - classifier_head_accuracy: 0.9542 - regressor_head_mse: 0.0081 - val_loss: 0.2480 - val_classifier_head_loss: 0.2383 - val_regressor_head_loss: 0.0097 - val_classifier_head_accuracy: 0.9062 - val_regressor_head_mse: 0.0097
# Epoch 31/100
# 28/28 [==============================] - 1s 25ms/step - loss: 0.1138 - classifier_head_loss: 0.1044 - regressor_head_loss: 0.0094 - classifier_head_accuracy: 0.9531 - regressor_head_mse: 0.0094 - val_loss: 0.3572 - val_classifier_head_loss: 0.3410 - val_regressor_head_loss: 0.0163 - val_classifier_head_accuracy: 0.9062 - val_regressor_head_mse: 0.0163
# Epoch 32/100
# 28/28 [==============================] - 1s 25ms/step - loss: 0.1717 - classifier_head_loss: 0.1602 - regressor_head_loss: 0.0114 - classifier_head_accuracy: 0.9364 - regressor_head_mse: 0.0114 - val_loss: 0.2150 - val_classifier_head_loss: 0.2034 - val_regressor_head_loss: 0.0116 - val_classifier_head_accuracy: 0.9219 - val_regressor_head_mse: 0.0116
# Epoch 33/100
# 28/28 [==============================] - 1s 25ms/step - loss: 0.1041 - classifier_head_loss: 0.0960 - regressor_head_loss: 0.0081 - classifier_head_accuracy: 0.9643 - regressor_head_mse: 0.0081 - val_loss: 0.3441 - val_classifier_head_loss: 0.3340 - val_regressor_head_loss: 0.0101 - val_classifier_head_accuracy: 0.8750 - val_regressor_head_mse: 0.0101
# Epoch 34/100
# 28/28 [==============================] - 1s 25ms/step - loss: 0.1134 - classifier_head_loss: 0.1039 - regressor_head_loss: 0.0095 - classifier_head_accuracy: 0.9621 - regressor_head_mse: 0.0095 - val_loss: 0.2868 - val_classifier_head_loss: 0.2774 - val_regressor_head_loss: 0.0095 - val_classifier_head_accuracy: 0.9062 - val_regressor_head_mse: 0.0095
# Epoch 35/100
# 28/28 [==============================] - 1s 25ms/step - loss: 0.1010 - classifier_head_loss: 0.0932 - regressor_head_loss: 0.0077 - classifier_head_accuracy: 0.9676 - regressor_head_mse: 0.0077 - val_loss: 0.2536 - val_classifier_head_loss: 0.2437 - val_regressor_head_loss: 0.0099 - val_classifier_head_accuracy: 0.9062 - val_regressor_head_mse: 0.0099
# Epoch 36/100
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0699 - classifier_head_loss: 0.0610 - regressor_head_loss: 0.0089 - classifier_head_accuracy: 0.9821 - regressor_head_mse: 0.0089 - val_loss: 0.2837 - val_classifier_head_loss: 0.2733 - val_regressor_head_loss: 0.0103 - val_classifier_head_accuracy: 0.8906 - val_regressor_head_mse: 0.0103
# Epoch 37/100
# 28/28 [==============================] - 1s 25ms/step - loss: 0.0936 - classifier_head_loss: 0.0851 - regressor_head_loss: 0.0085 - classifier_head_accuracy: 0.9676 - regressor_head_mse: 0.0085 - val_loss: 0.3165 - val_classifier_head_loss: 0.3058 - val_regressor_head_loss: 0.0107 - val_classifier_head_accuracy: 0.8906 - val_regressor_head_mse: 0.0107
# Epoch 38/100
# 28/28 [==============================] - 1s 26ms/step - loss: 0.1010 - classifier_head_loss: 0.0901 - regressor_head_loss: 0.0109 - classifier_head_accuracy: 0.9587 - regressor_head_mse: 0.0109 - val_loss: 0.2350 - val_classifier_head_loss: 0.2207 - val_regressor_head_loss: 0.0144 - val_classifier_head_accuracy: 0.9062 - val_regressor_head_mse: 0.0144
# Epoch 39/100
# 28/28 [==============================] - 1s 25ms/step - loss: 0.0615 - classifier_head_loss: 0.0535 - regressor_head_loss: 0.0080 - classifier_head_accuracy: 0.9855 - regressor_head_mse: 0.0080 - val_loss: 0.3233 - val_classifier_head_loss: 0.3123 - val_regressor_head_loss: 0.0110 - val_classifier_head_accuracy: 0.9219 - val_regressor_head_mse: 0.0110
# Epoch 40/100
# 28/28 [==============================] - 1s 25ms/step - loss: 0.0657 - classifier_head_loss: 0.0579 - regressor_head_loss: 0.0078 - classifier_head_accuracy: 0.9766 - regressor_head_mse: 0.0078 - val_loss: 0.2685 - val_classifier_head_loss: 0.2578 - val_regressor_head_loss: 0.0107 - val_classifier_head_accuracy: 0.9062 - val_regressor_head_mse: 0.0107
# Epoch 41/100
# 28/28 [==============================] - 1s 27ms/step - loss: 0.0771 - classifier_head_loss: 0.0669 - regressor_head_loss: 0.0103 - classifier_head_accuracy: 0.9754 - regressor_head_mse: 0.0103 - val_loss: 0.3488 - val_classifier_head_loss: 0.3341 - val_regressor_head_loss: 0.0148 - val_classifier_head_accuracy: 0.8594 - val_regressor_head_mse: 0.0148
# Epoch 42/100
# 28/28 [==============================] - 1s 30ms/step - loss: 0.0617 - classifier_head_loss: 0.0531 - regressor_head_loss: 0.0087 - classifier_head_accuracy: 0.9788 - regressor_head_mse: 0.0087 - val_loss: 0.2890 - val_classifier_head_loss: 0.2797 - val_regressor_head_loss: 0.0093 - val_classifier_head_accuracy: 0.9219 - val_regressor_head_mse: 0.0093
# Epoch 43/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.0400 - classifier_head_loss: 0.0326 - regressor_head_loss: 0.0074 - classifier_head_accuracy: 0.9911 - regressor_head_mse: 0.0074 - val_loss: 0.3117 - val_classifier_head_loss: 0.3016 - val_regressor_head_loss: 0.0101 - val_classifier_head_accuracy: 0.9219 - val_regressor_head_mse: 0.0101
# Epoch 44/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.0511 - classifier_head_loss: 0.0421 - regressor_head_loss: 0.0090 - classifier_head_accuracy: 0.9855 - regressor_head_mse: 0.0090 - val_loss: 0.4302 - val_classifier_head_loss: 0.4066 - val_regressor_head_loss: 0.0236 - val_classifier_head_accuracy: 0.9062 - val_regressor_head_mse: 0.0236
# Epoch 45/100
# 28/28 [==============================] - 1s 35ms/step - loss: 0.0522 - classifier_head_loss: 0.0416 - regressor_head_loss: 0.0106 - classifier_head_accuracy: 0.9866 - regressor_head_mse: 0.0106 - val_loss: 0.3110 - val_classifier_head_loss: 0.2996 - val_regressor_head_loss: 0.0114 - val_classifier_head_accuracy: 0.9062 - val_regressor_head_mse: 0.0114
# Epoch 46/100
# 28/28 [==============================] - 1s 34ms/step - loss: 0.0712 - classifier_head_loss: 0.0633 - regressor_head_loss: 0.0079 - classifier_head_accuracy: 0.9732 - regressor_head_mse: 0.0079 - val_loss: 0.4330 - val_classifier_head_loss: 0.4237 - val_regressor_head_loss: 0.0093 - val_classifier_head_accuracy: 0.8750 - val_regressor_head_mse: 0.0093
# Epoch 47/100
# 28/28 [==============================] - 1s 33ms/step - loss: 0.0459 - classifier_head_loss: 0.0390 - regressor_head_loss: 0.0069 - classifier_head_accuracy: 0.9888 - regressor_head_mse: 0.0069 - val_loss: 0.3631 - val_classifier_head_loss: 0.3541 - val_regressor_head_loss: 0.0090 - val_classifier_head_accuracy: 0.9062 - val_regressor_head_mse: 0.0090
# Epoch 48/100
# 28/28 [==============================] - 1s 29ms/step - loss: 0.0381 - classifier_head_loss: 0.0311 - regressor_head_loss: 0.0070 - classifier_head_accuracy: 0.9922 - regressor_head_mse: 0.0070 - val_loss: 0.3551 - val_classifier_head_loss: 0.3433 - val_regressor_head_loss: 0.0118 - val_classifier_head_accuracy: 0.9062 - val_regressor_head_mse: 0.0118
# Epoch 49/100
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0814 - classifier_head_loss: 0.0716 - regressor_head_loss: 0.0099 - classifier_head_accuracy: 0.9732 - regressor_head_mse: 0.0099 - val_loss: 0.3578 - val_classifier_head_loss: 0.3477 - val_regressor_head_loss: 0.0100 - val_classifier_head_accuracy: 0.9062 - val_regressor_head_mse: 0.0100
# Epoch 50/100
# 28/28 [==============================] - 1s 27ms/step - loss: 0.0487 - classifier_head_loss: 0.0407 - regressor_head_loss: 0.0081 - classifier_head_accuracy: 0.9866 - regressor_head_mse: 0.0081 - val_loss: 0.3870 - val_classifier_head_loss: 0.3733 - val_regressor_head_loss: 0.0137 - val_classifier_head_accuracy: 0.9375 - val_regressor_head_mse: 0.0137
# Epoch 51/100
# 28/28 [==============================] - 1s 25ms/step - loss: 0.0338 - classifier_head_loss: 0.0260 - regressor_head_loss: 0.0078 - classifier_head_accuracy: 0.9922 - regressor_head_mse: 0.0078 - val_loss: 0.3459 - val_classifier_head_loss: 0.3345 - val_regressor_head_loss: 0.0113 - val_classifier_head_accuracy: 0.9062 - val_regressor_head_mse: 0.0113
# Epoch 52/100
# 28/28 [==============================] - 1s 27ms/step - loss: 0.0276 - classifier_head_loss: 0.0206 - regressor_head_loss: 0.0070 - classifier_head_accuracy: 0.9955 - regressor_head_mse: 0.0070 - val_loss: 0.3092 - val_classifier_head_loss: 0.2989 - val_regressor_head_loss: 0.0103 - val_classifier_head_accuracy: 0.9219 - val_regressor_head_mse: 0.0103
# Epoch 53/100
# 28/28 [==============================] - 1s 28ms/step - loss: 0.0239 - classifier_head_loss: 0.0174 - regressor_head_loss: 0.0065 - classifier_head_accuracy: 0.9967 - regressor_head_mse: 0.0065 - val_loss: 0.3666 - val_classifier_head_loss: 0.3532 - val_regressor_head_loss: 0.0134 - val_classifier_head_accuracy: 0.9219 - val_regressor_head_mse: 0.0134
# Epoch 54/100
# 28/28 [==============================] - 1s 25ms/step - loss: 0.0303 - classifier_head_loss: 0.0237 - regressor_head_loss: 0.0066 - classifier_head_accuracy: 0.9944 - regressor_head_mse: 0.0066 - val_loss: 0.4067 - val_classifier_head_loss: 0.3946 - val_regressor_head_loss: 0.0121 - val_classifier_head_accuracy: 0.9219 - val_regressor_head_mse: 0.0121
# Epoch 55/100
# 28/28 [==============================] - 1s 27ms/step - loss: 0.0237 - classifier_head_loss: 0.0162 - regressor_head_loss: 0.0075 - classifier_head_accuracy: 0.9967 - regressor_head_mse: 0.0075 - val_loss: 0.3278 - val_classifier_head_loss: 0.3169 - val_regressor_head_loss: 0.0108 - val_classifier_head_accuracy: 0.9062 - val_regressor_head_mse: 0.0108
# Epoch 56/100
# 28/28 [==============================] - 1s 27ms/step - loss: 0.0450 - classifier_head_loss: 0.0371 - regressor_head_loss: 0.0079 - classifier_head_accuracy: 0.9877 - regressor_head_mse: 0.0079 - val_loss: 0.4601 - val_classifier_head_loss: 0.4477 - val_regressor_head_loss: 0.0125 - val_classifier_head_accuracy: 0.9219 - val_regressor_head_mse: 0.0125
# Epoch 57/100
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0363 - classifier_head_loss: 0.0292 - regressor_head_loss: 0.0072 - classifier_head_accuracy: 0.9944 - regressor_head_mse: 0.0072 - val_loss: 0.4180 - val_classifier_head_loss: 0.4079 - val_regressor_head_loss: 0.0101 - val_classifier_head_accuracy: 0.8906 - val_regressor_head_mse: 0.0101
# Epoch 58/100
# 28/28 [==============================] - 1s 28ms/step - loss: 0.0591 - classifier_head_loss: 0.0512 - regressor_head_loss: 0.0079 - classifier_head_accuracy: 0.9788 - regressor_head_mse: 0.0079 - val_loss: 0.3349 - val_classifier_head_loss: 0.3232 - val_regressor_head_loss: 0.0117 - val_classifier_head_accuracy: 0.9062 - val_regressor_head_mse: 0.0117
# Epoch 59/100
# 28/28 [==============================] - 1s 28ms/step - loss: 0.0251 - classifier_head_loss: 0.0184 - regressor_head_loss: 0.0067 - classifier_head_accuracy: 0.9978 - regressor_head_mse: 0.0067 - val_loss: 0.3431 - val_classifier_head_loss: 0.3330 - val_regressor_head_loss: 0.0101 - val_classifier_head_accuracy: 0.9219 - val_regressor_head_mse: 0.0101
# Epoch 60/100
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0191 - classifier_head_loss: 0.0120 - regressor_head_loss: 0.0071 - classifier_head_accuracy: 0.9978 - regressor_head_mse: 0.0071 - val_loss: 0.4135 - val_classifier_head_loss: 0.4031 - val_regressor_head_loss: 0.0104 - val_classifier_head_accuracy: 0.8906 - val_regressor_head_mse: 0.0104
# Epoch 61/100
# 28/28 [==============================] - 1s 27ms/step - loss: 0.0256 - classifier_head_loss: 0.0177 - regressor_head_loss: 0.0079 - classifier_head_accuracy: 0.9922 - regressor_head_mse: 0.0079 - val_loss: 0.3747 - val_classifier_head_loss: 0.3637 - val_regressor_head_loss: 0.0110 - val_classifier_head_accuracy: 0.9062 - val_regressor_head_mse: 0.0110
# Epoch 62/100
# 28/28 [==============================] - 1s 33ms/step - loss: 0.0191 - classifier_head_loss: 0.0118 - regressor_head_loss: 0.0073 - classifier_head_accuracy: 0.9978 - regressor_head_mse: 0.0073 - val_loss: 0.4522 - val_classifier_head_loss: 0.4382 - val_regressor_head_loss: 0.0140 - val_classifier_head_accuracy: 0.9062 - val_regressor_head_mse: 0.0140
# Epoch 63/100
# 28/28 [==============================] - 1s 33ms/step - loss: 0.0126 - classifier_head_loss: 0.0068 - regressor_head_loss: 0.0058 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0058 - val_loss: 0.3811 - val_classifier_head_loss: 0.3710 - val_regressor_head_loss: 0.0100 - val_classifier_head_accuracy: 0.9062 - val_regressor_head_mse: 0.0100
# Epoch 64/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.0123 - classifier_head_loss: 0.0065 - regressor_head_loss: 0.0058 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0058 - val_loss: 0.3911 - val_classifier_head_loss: 0.3817 - val_regressor_head_loss: 0.0094 - val_classifier_head_accuracy: 0.8906 - val_regressor_head_mse: 0.0094
# Epoch 65/100
# 28/28 [==============================] - 1s 34ms/step - loss: 0.0120 - classifier_head_loss: 0.0066 - regressor_head_loss: 0.0054 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0054 - val_loss: 0.4351 - val_classifier_head_loss: 0.4239 - val_regressor_head_loss: 0.0112 - val_classifier_head_accuracy: 0.9375 - val_regressor_head_mse: 0.0112
# Epoch 66/100
# 28/28 [==============================] - 1s 35ms/step - loss: 0.0181 - classifier_head_loss: 0.0120 - regressor_head_loss: 0.0061 - classifier_head_accuracy: 0.9967 - regressor_head_mse: 0.0061 - val_loss: 0.4575 - val_classifier_head_loss: 0.4470 - val_regressor_head_loss: 0.0105 - val_classifier_head_accuracy: 0.8906 - val_regressor_head_mse: 0.0105
# Epoch 67/100
# 28/28 [==============================] - 1s 35ms/step - loss: 0.0245 - classifier_head_loss: 0.0189 - regressor_head_loss: 0.0056 - classifier_head_accuracy: 0.9933 - regressor_head_mse: 0.0056 - val_loss: 0.4303 - val_classifier_head_loss: 0.4189 - val_regressor_head_loss: 0.0114 - val_classifier_head_accuracy: 0.9219 - val_regressor_head_mse: 0.0114
# Epoch 68/100
# 28/28 [==============================] - 1s 41ms/step - loss: 0.0131 - classifier_head_loss: 0.0076 - regressor_head_loss: 0.0056 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0056 - val_loss: 0.4496 - val_classifier_head_loss: 0.4395 - val_regressor_head_loss: 0.0101 - val_classifier_head_accuracy: 0.8750 - val_regressor_head_mse: 0.0101
# Epoch 69/100
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0108 - classifier_head_loss: 0.0054 - regressor_head_loss: 0.0054 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0054 - val_loss: 0.4632 - val_classifier_head_loss: 0.4499 - val_regressor_head_loss: 0.0133 - val_classifier_head_accuracy: 0.8906 - val_regressor_head_mse: 0.0133
# Epoch 70/100
# 28/28 [==============================] - 1s 40ms/step - loss: 0.0077 - classifier_head_loss: 0.0022 - regressor_head_loss: 0.0056 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0056 - val_loss: 0.4206 - val_classifier_head_loss: 0.4102 - val_regressor_head_loss: 0.0104 - val_classifier_head_accuracy: 0.8906 - val_regressor_head_mse: 0.0104
# Epoch 71/100
# 28/28 [==============================] - 1s 27ms/step - loss: 0.0142 - classifier_head_loss: 0.0072 - regressor_head_loss: 0.0070 - classifier_head_accuracy: 0.9978 - regressor_head_mse: 0.0070 - val_loss: 0.4235 - val_classifier_head_loss: 0.4136 - val_regressor_head_loss: 0.0100 - val_classifier_head_accuracy: 0.9219 - val_regressor_head_mse: 0.0100
# Epoch 72/100
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0116 - classifier_head_loss: 0.0063 - regressor_head_loss: 0.0054 - classifier_head_accuracy: 0.9989 - regressor_head_mse: 0.0054 - val_loss: 0.5874 - val_classifier_head_loss: 0.5780 - val_regressor_head_loss: 0.0094 - val_classifier_head_accuracy: 0.9219 - val_regressor_head_mse: 0.0094
# Epoch 73/100
# 28/28 [==============================] - 1s 25ms/step - loss: 0.0101 - classifier_head_loss: 0.0053 - regressor_head_loss: 0.0048 - classifier_head_accuracy: 0.9989 - regressor_head_mse: 0.0048 - val_loss: 0.3868 - val_classifier_head_loss: 0.3773 - val_regressor_head_loss: 0.0095 - val_classifier_head_accuracy: 0.8906 - val_regressor_head_mse: 0.0095
# Epoch 74/100
# 28/28 [==============================] - 1s 25ms/step - loss: 0.0099 - classifier_head_loss: 0.0040 - regressor_head_loss: 0.0059 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0059 - val_loss: 0.4912 - val_classifier_head_loss: 0.4798 - val_regressor_head_loss: 0.0114 - val_classifier_head_accuracy: 0.8906 - val_regressor_head_mse: 0.0114
# Epoch 75/100
# 28/28 [==============================] - 1s 27ms/step - loss: 0.0118 - classifier_head_loss: 0.0065 - regressor_head_loss: 0.0053 - classifier_head_accuracy: 0.9967 - regressor_head_mse: 0.0053 - val_loss: 0.5808 - val_classifier_head_loss: 0.5718 - val_regressor_head_loss: 0.0090 - val_classifier_head_accuracy: 0.8906 - val_regressor_head_mse: 0.0090
# Epoch 76/100
# 28/28 [==============================] - 1s 25ms/step - loss: 0.0077 - classifier_head_loss: 0.0029 - regressor_head_loss: 0.0048 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0048 - val_loss: 0.5079 - val_classifier_head_loss: 0.4986 - val_regressor_head_loss: 0.0093 - val_classifier_head_accuracy: 0.9062 - val_regressor_head_mse: 0.0093
# Epoch 77/100
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0091 - classifier_head_loss: 0.0047 - regressor_head_loss: 0.0044 - classifier_head_accuracy: 0.9989 - regressor_head_mse: 0.0044 - val_loss: 0.5125 - val_classifier_head_loss: 0.5026 - val_regressor_head_loss: 0.0099 - val_classifier_head_accuracy: 0.9062 - val_regressor_head_mse: 0.0099
# Epoch 78/100
# 28/28 [==============================] - 1s 24ms/step - loss: 0.0061 - classifier_head_loss: 0.0018 - regressor_head_loss: 0.0043 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0043 - val_loss: 0.4092 - val_classifier_head_loss: 0.3996 - val_regressor_head_loss: 0.0096 - val_classifier_head_accuracy: 0.8906 - val_regressor_head_mse: 0.0096
# Epoch 79/100
# 28/28 [==============================] - 1s 24ms/step - loss: 0.0066 - classifier_head_loss: 0.0024 - regressor_head_loss: 0.0042 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0042 - val_loss: 0.4827 - val_classifier_head_loss: 0.4729 - val_regressor_head_loss: 0.0098 - val_classifier_head_accuracy: 0.9062 - val_regressor_head_mse: 0.0098
# Epoch 80/100
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0070 - classifier_head_loss: 0.0023 - regressor_head_loss: 0.0047 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0047 - val_loss: 0.4231 - val_classifier_head_loss: 0.4117 - val_regressor_head_loss: 0.0114 - val_classifier_head_accuracy: 0.8906 - val_regressor_head_mse: 0.0114
# Epoch 81/100
# 28/28 [==============================] - 1s 29ms/step - loss: 0.0106 - classifier_head_loss: 0.0031 - regressor_head_loss: 0.0075 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0075 - val_loss: 0.3935 - val_classifier_head_loss: 0.3754 - val_regressor_head_loss: 0.0181 - val_classifier_head_accuracy: 0.8906 - val_regressor_head_mse: 0.0181
# Epoch 82/100
# 28/28 [==============================] - 1s 30ms/step - loss: 0.0140 - classifier_head_loss: 0.0036 - regressor_head_loss: 0.0104 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0104 - val_loss: 0.4775 - val_classifier_head_loss: 0.4627 - val_regressor_head_loss: 0.0148 - val_classifier_head_accuracy: 0.8906 - val_regressor_head_mse: 0.0148
# Epoch 83/100
# 28/28 [==============================] - 1s 30ms/step - loss: 0.0095 - classifier_head_loss: 0.0038 - regressor_head_loss: 0.0057 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0057 - val_loss: 0.4087 - val_classifier_head_loss: 0.3989 - val_regressor_head_loss: 0.0098 - val_classifier_head_accuracy: 0.8750 - val_regressor_head_mse: 0.0098
# Epoch 84/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.0068 - classifier_head_loss: 0.0024 - regressor_head_loss: 0.0044 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0044 - val_loss: 0.4838 - val_classifier_head_loss: 0.4752 - val_regressor_head_loss: 0.0086 - val_classifier_head_accuracy: 0.9062 - val_regressor_head_mse: 0.0086
# Epoch 85/100
# 28/28 [==============================] - 1s 33ms/step - loss: 0.0065 - classifier_head_loss: 0.0027 - regressor_head_loss: 0.0039 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0039 - val_loss: 0.4565 - val_classifier_head_loss: 0.4466 - val_regressor_head_loss: 0.0099 - val_classifier_head_accuracy: 0.8906 - val_regressor_head_mse: 0.0099
# Epoch 86/100
# 28/28 [==============================] - 1s 34ms/step - loss: 0.0073 - classifier_head_loss: 0.0031 - regressor_head_loss: 0.0042 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0042 - val_loss: 0.5433 - val_classifier_head_loss: 0.5334 - val_regressor_head_loss: 0.0099 - val_classifier_head_accuracy: 0.8906 - val_regressor_head_mse: 0.0099
# Epoch 87/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.0071 - classifier_head_loss: 0.0030 - regressor_head_loss: 0.0041 - classifier_head_accuracy: 0.9989 - regressor_head_mse: 0.0041 - val_loss: 0.4516 - val_classifier_head_loss: 0.4420 - val_regressor_head_loss: 0.0097 - val_classifier_head_accuracy: 0.8906 - val_regressor_head_mse: 0.0097
# Epoch 88/100
# 28/28 [==============================] - 1s 28ms/step - loss: 0.0081 - classifier_head_loss: 0.0042 - regressor_head_loss: 0.0039 - classifier_head_accuracy: 0.9989 - regressor_head_mse: 0.0039 - val_loss: 0.5422 - val_classifier_head_loss: 0.5333 - val_regressor_head_loss: 0.0090 - val_classifier_head_accuracy: 0.9062 - val_regressor_head_mse: 0.0090
# Epoch 89/100
# 28/28 [==============================] - 1s 25ms/step - loss: 0.0089 - classifier_head_loss: 0.0047 - regressor_head_loss: 0.0042 - classifier_head_accuracy: 0.9978 - regressor_head_mse: 0.0042 - val_loss: 0.4614 - val_classifier_head_loss: 0.4516 - val_regressor_head_loss: 0.0098 - val_classifier_head_accuracy: 0.9062 - val_regressor_head_mse: 0.0098
# Epoch 90/100
# 28/28 [==============================] - 1s 27ms/step - loss: 0.0054 - classifier_head_loss: 0.0019 - regressor_head_loss: 0.0035 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0035 - val_loss: 0.5147 - val_classifier_head_loss: 0.5058 - val_regressor_head_loss: 0.0089 - val_classifier_head_accuracy: 0.9062 - val_regressor_head_mse: 0.0089
# Epoch 91/100
# 28/28 [==============================] - 1s 24ms/step - loss: 0.0075 - classifier_head_loss: 0.0038 - regressor_head_loss: 0.0037 - classifier_head_accuracy: 0.9989 - regressor_head_mse: 0.0037 - val_loss: 0.4156 - val_classifier_head_loss: 0.4057 - val_regressor_head_loss: 0.0099 - val_classifier_head_accuracy: 0.8906 - val_regressor_head_mse: 0.0099
# Epoch 92/100
# 28/28 [==============================] - 1s 25ms/step - loss: 0.0084 - classifier_head_loss: 0.0046 - regressor_head_loss: 0.0038 - classifier_head_accuracy: 0.9989 - regressor_head_mse: 0.0038 - val_loss: 0.4719 - val_classifier_head_loss: 0.4629 - val_regressor_head_loss: 0.0090 - val_classifier_head_accuracy: 0.8906 - val_regressor_head_mse: 0.0090
# Epoch 93/100
# 28/28 [==============================] - 1s 27ms/step - loss: 0.0054 - classifier_head_loss: 0.0018 - regressor_head_loss: 0.0036 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0036 - val_loss: 0.4651 - val_classifier_head_loss: 0.4553 - val_regressor_head_loss: 0.0098 - val_classifier_head_accuracy: 0.9062 - val_regressor_head_mse: 0.0098
# Epoch 94/100
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0070 - classifier_head_loss: 0.0025 - regressor_head_loss: 0.0045 - classifier_head_accuracy: 0.9989 - regressor_head_mse: 0.0045 - val_loss: 0.4685 - val_classifier_head_loss: 0.4590 - val_regressor_head_loss: 0.0095 - val_classifier_head_accuracy: 0.9062 - val_regressor_head_mse: 0.0095
# Epoch 95/100
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0112 - classifier_head_loss: 0.0073 - regressor_head_loss: 0.0039 - classifier_head_accuracy: 0.9967 - regressor_head_mse: 0.0039 - val_loss: 0.5235 - val_classifier_head_loss: 0.5136 - val_regressor_head_loss: 0.0099 - val_classifier_head_accuracy: 0.9062 - val_regressor_head_mse: 0.0099
# Epoch 96/100
# 28/28 [==============================] - 1s 26ms/step - loss: 0.1323 - classifier_head_loss: 0.1216 - regressor_head_loss: 0.0108 - classifier_head_accuracy: 0.9554 - regressor_head_mse: 0.0108 - val_loss: 0.3415 - val_classifier_head_loss: 0.3055 - val_regressor_head_loss: 0.0361 - val_classifier_head_accuracy: 0.8906 - val_regressor_head_mse: 0.0361
# Epoch 97/100
# 28/28 [==============================] - 1s 25ms/step - loss: 0.1527 - classifier_head_loss: 0.1412 - regressor_head_loss: 0.0116 - classifier_head_accuracy: 0.9587 - regressor_head_mse: 0.0116 - val_loss: 0.4963 - val_classifier_head_loss: 0.4855 - val_regressor_head_loss: 0.0108 - val_classifier_head_accuracy: 0.8750 - val_regressor_head_mse: 0.0108
# Epoch 98/100
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0574 - classifier_head_loss: 0.0502 - regressor_head_loss: 0.0072 - classifier_head_accuracy: 0.9810 - regressor_head_mse: 0.0072 - val_loss: 0.4246 - val_classifier_head_loss: 0.4150 - val_regressor_head_loss: 0.0096 - val_classifier_head_accuracy: 0.9062 - val_regressor_head_mse: 0.0096
# Epoch 99/100
# 28/28 [==============================] - 1s 25ms/step - loss: 0.0258 - classifier_head_loss: 0.0202 - regressor_head_loss: 0.0056 - classifier_head_accuracy: 0.9944 - regressor_head_mse: 0.0056 - val_loss: 0.4929 - val_classifier_head_loss: 0.4830 - val_regressor_head_loss: 0.0099 - val_classifier_head_accuracy: 0.9062 - val_regressor_head_mse: 0.0099
# Epoch 100/100
# 28/28 [==============================] - 1s 30ms/step - loss: 0.0177 - classifier_head_loss: 0.0130 - regressor_head_loss: 0.0048 - classifier_head_accuracy: 0.9989 - regressor_head_mse: 0.0048 - val_loss: 0.4670 - val_classifier_head_loss: 0.4579 - val_regressor_head_loss: 0.0091 - val_classifier_head_accuracy: 0.8906 - val_regressor_head_mse: 0.0091

# %% [markdown]
# ## IoU Metric

# %% [markdown]
# IoU scores how well the predicted bound box overlaps the actual bound box. The idea behind IoU is pretty simple: compare the intersection and union areas between the predicted and actual bound boxes by dividing the intersection by the union. IoU provides a higher score always when the predicted bounding box best matches the actual bounding box (also called ground-truth)

# %%
def intersection_over_union(boxA, boxB):
	xA = max(boxA[0], boxB[0])
	yA = max(boxA[1], boxB[1])
	xB = min(boxA[0] + boxA[2], boxB[0] + boxB[2])
	yB = min(boxA[1] + boxA[3], boxB[1] + boxB[3])

	interArea = (xB-xA)*(yB-yA)# Calculate Intersection Area
	boxAArea = boxA[2]*boxA[3]# Calcualate BoxA Area
	boxBArea = boxB[2]*boxB[3]# Calculate BoxB Area
	for i in [interArea,boxAArea,boxBArea]:
		if i<0:
			i=0
	iou = (float)(interArea)/(boxAArea+boxBArea-interArea)# Find IOU

	return iou

# %% [markdown]
# ## Prediction

# %%
plt.figure(figsize=(12, 10))

test_list = list(test_ds.take(20).as_numpy_iterator())

image, labels = test_list[0]

for i in range(len(test_list)):

    ax = plt.subplot(4, 5, i + 1)
    image, labels = test_list[i]

    predictions = model(image)

    predicted_box = predictions[1][0] * input_size
    predicted_box = tf.cast(predicted_box, tf.int32)

    predicted_label = predictions[0][0]

    image = image[0]

    actual_label = labels[0][0]
    actual_box = labels[1][0] * input_size
    actual_box = tf.cast(actual_box, tf.int32)

    image = image.astype("float") * 255.0
    image = image.astype(np.uint8)
    image_color = cv.cvtColor(image, cv.COLOR_GRAY2RGB)

    color = (255, 0, 0)
    # print box red if predicted and actual label do not match
    if (predicted_label[0] > 0.5 and actual_label[0] > 0) or (predicted_label[0] < 0.5 and actual_label[0] == 0):
        color = (0, 255, 0)

    img_label = "unmasked"
    if predicted_label[0] > 0.5:
        img_label = "masked"

    predicted_box_n = predicted_box.numpy()
    cv.rectangle(image_color, predicted_box_n, color, 2)
    cv.rectangle(image_color, actual_box.numpy(), (0, 0, 255), 2)
    cv.rectangle(image_color, (predicted_box_n[0], predicted_box_n[1] + predicted_box_n[3] - 20), (predicted_box_n[0] + predicted_box_n[2], predicted_box_n[1] + predicted_box_n[3]), color, -1)
    cv.putText(image_color, img_label, (predicted_box_n[0] + 5, predicted_box_n[1] + predicted_box_n[3] - 5), cv.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 0))

    IoU = intersection_over_union(predicted_box.numpy(), actual_box.numpy())

    plt.title("IoU:" + format(IoU, '.4f'))
    plt.imshow(image_color)
    plt.axis("off")

# %% [markdown]
# # RESEARCH WORK:
# Find out about Common Problems in Segmentation and Object Detection and the Solution for the same. Also Find how these Models can be used for Image Generation within GANs and VAEs.
